# %%
getwd()
# Out:
# [1] "/Users/abhavluthra/Desktop/DIC/lab1/lab1part2"

# %%
options(warn=-1)

# %%
#gpclibPermit()
#install.packages("RCurl", repos='http://cran.us.r-project.org')
#install.packages("rgeos", repos='http://cran.us.r-project.org')
install.packages("ggplot2", repos='http://cran.us.r-project.org')
install.packages("maptools", repos='http://cran.us.r-project.org')
install.packages("ggmap", repos='http://cran.us.r-project.org')
install.packages("twitteR", repos='http://cran.us.r-project.org')
install.packages("maps", repos='http://cran.us.r-project.org')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependencies ‘bit’, ‘bit64’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(ggplot2)
library("maptools")
library(maps)
library(twitteR)
library(ggmap)
# Out:
# Loading required package: sp
# Checking rgeos availability: FALSE
#  	Note: when rgeos is not available, polygon geometry 	computations in maptools depend on gpclib,
#  	which has a restricted licence. It is disabled by default;
#  	to enable gpclib, type gpclibPermit()
# Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
# Please cite ggmap if you use it! See citation("ggmap") for details.

# %%
gpclibPermit()
# Out:
# [1] FALSE

# %%
setup_twitter_oauth("zYQ0FKsLlvUqay4c7ouLWmo7s", "pgutd6hCTSZlHbvVvlkO21QSz7TcsXTIQSY83gtY0D59OKAUxo", 
"843151334-ynfmS3g8t0SExOeIAb7CejTDB6umzF1JDyguxJV4", "nJ4Z2vdBM9WXVzBGli2w2Aw0r18d7xafYuOHGMfWRboq8")
influenzaTweets <- searchTwitter("#influenza", n=10000, since='2019-01-01') #retrieve first tweets
df1_influenzaTweets <- twListToDF(influenzaTweets)
# Out:
# [1] "Using direct authentication"

# %%
write.csv(df1_influenzaTweets, file = "/Users/abhavluthra/Desktop/DIC/lab1/lab1part2/df1_influenzaTweets1.csv", row.names=FALSE, na="")

# %%
#look up users from tweets dataframes using screenName
users.data <- lookupUsers(df1_influenzaTweets$screenName) 
userData <- twListToDF(users.data)
userLocations <- userData$location 
head(userData)
# Out:
#                 description
# CatchBreath60   Respiratory, pulmonary disease/ COPD\U0001f397\nSCA \U0001f494Rightsided Heart Failure\U0001f494 PH\n\U0001f4bbWeekly Blog @ https://t.co/oR9F6mK5F6\n\U0001f4faYou Tube @Catchyourbreath60
# whitetrashart   American artist, writer, and pop culture enthusiast White Trash Peg
# elihernantorres
# 03Jurisdiccion
# PasiaMorelos    Para mi un equipo que se preocupa x los niñitos y adolescentes del Estado...unidos x una preocupación real y movidos x el deseo genuino de que ellos estén mejor
# censia_salud    Centro Nacional para la Salud de la Infancia y la Adolescencia de la Secretaría de Salud.
#                 statusesCount followersCount favoritesCount friendsCount
# CatchBreath60    1221           274           5205          293
# whitetrashart    4999           228           4731          414
# elihernantorres 12553           345          16857          397
# 03Jurisdiccion   2569            62             29          241
# PasiaMorelos     7950            97           7925           81
# censia_salud    14924         13390           4744          397
#                 url
# CatchBreath60   https://t.co/PMi9ExKuZa
# whitetrashart   https://t.co/BTPdAewYAy
# elihernantorres NA
# 03Jurisdiccion  NA
# PasiaMorelos    https://t.co/n7f2qdXGSx
# censia_salud    https://t.co/RFEyT6NgJg
#                 name
# CatchBreath60   CatchYourBreath60 \U0001f397 C.O.P.D \U0001f494 Heart Disease
# whitetrashart   White Trash Peg
# elihernantorres Liztilla
# 03Jurisdiccion  JURISDICCION SANITARIA 03
# PasiaMorelos    Dasia Morelos
# censia_salud    CeNSIA
#                 created             protected verified screenName
# CatchBreath60   2017-09-17 19:14:49 FALSE     FALSE    CatchBreath60
# whitetrashart   2008-04-18 16:20:56 FALSE     FALSE    whitetrashart
# elihernantorres 2013-06-11 22:02:09 FALSE     FALSE    elihernantorres
# 03Jurisdiccion  2018-02-20 05:32:29 FALSE     FALSE    03Jurisdiccion
# PasiaMorelos    2014-07-31 00:21:14 FALSE     FALSE    PasiaMorelos
# censia_salud    2012-05-08 19:52:34 FALSE      TRUE    censia_salud
#                 location                    lang id                 listedCount
# CatchBreath60   Hamilton, Ontario           en   909495878045532166   4
# whitetrashart   Illinois, USA               en   14434759             3
# elihernantorres                             es   1507077998           5
# 03Jurisdiccion                              es   965821435825479680   0
# PasiaMorelos    Gustavo Gomez Azcarate #205 es   2729498249           8
# censia_salud    Ciudad de México            es   574747417          132
#                 followRequestSent
# CatchBreath60   FALSE
# whitetrashart   FALSE
# elihernantorres FALSE
# 03Jurisdiccion  FALSE
# PasiaMorelos    FALSE
# censia_salud    FALSE
#                 profileImageUrl
# CatchBreath60   http://pbs.twimg.com/profile_images/909503711763984384/aY4WEv-C_normal.jpg
# whitetrashart   http://pbs.twimg.com/profile_images/1085689522132844545/_zGJPB4j_normal.jpg
# elihernantorres http://pbs.twimg.com/profile_images/917793371506196480/KsJSBf57_normal.jpg
# 03Jurisdiccion  http://pbs.twimg.com/profile_images/1082491604135374849/7ZRtPWXD_normal.jpg
# PasiaMorelos    http://pbs.twimg.com/profile_images/1095338679172616192/d4bRCsq6_normal.jpg
# censia_salud    http://pbs.twimg.com/profile_images/1072601150384431104/MNJUlm83_normal.jpg

# %%
#Remove the empty location
userLocations1 <- userLocations[userLocations!='']
head(userLocations1)
# Out:
# [1] "Hamilton, Ontario"           "Illinois, USA"
# [3] "Gustavo Gomez Azcarate #205" "Ciudad de México"
# [5] "Rome, Italy"                 "London, England"

# %%
#convert it into data frame and save into csv
df1_userLocations1 <- as.data.frame(userLocations1)
write.csv(df1_userLocations1, file = "df1_userLocations1.csv",row.names=FALSE, na="")

# %%
#Getting long and lat of all the locations using google api(geocode)
df_location <-read.csv(file="df1_userLocations1.csv")
head(df_location)
register_google(key = 'AIzaSyB6mJD3w8xlutjeUbyj-ue9Ldhd3gRLQjE') 
geoloc1 <- geocode(as.character(df_location$userLocations))
# Out:
#   userLocations1
# 1 Hamilton, Ontario
# 2 Illinois, USA
# 3 Gustavo Gomez Azcarate #205
# 4 Ciudad de México
# 5 Rome, Italy
# 6 London, England
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Hamilton,+Ontario&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Illinois,+USA&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Gustavo+Gomez+Azcarate+#205&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Ciudad+de+M%C3%A9xico&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Rome,+Italy&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=London,+England&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Philadelphia,+PA&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Ecuador&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Guadalajara,+Jalisco&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=
key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Gits&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Stockholm,+Sweden&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Sydney+Nova+Scotia&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Jamaica&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Toronto,+Ontario&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Australia&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Stop+Pree+Mi&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=A+sud+del+Polo+Nord&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Jamrock&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Mother+Earth&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Jamaica&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Melbourne,+Victoria&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Kingston,+Jamaica&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Jamaica&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Spanish+Town,+Italy&key=xxx-ue9Ldhd3gRLQjE
# "Spanish Town, Italy" not uniquely geocoded, using "spain"
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Kingston,+Jamaica&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Madrid&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Turin,+Italy&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=California,+USA&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=UpperEchelon+*+WV&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Regensburg,+Germany&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Germany&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Saint+Louis,+MO&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Distrito+Federal,+M%C3%A9xico&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Deutschland&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Germany&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Mainz,+Germany&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Roma&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Waddinxveen&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Milano-Roma&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Roma,+Lazio&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Northamptonshire&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Venise&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Comunidad+de+Madrid,+Espa%C3%B1a&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Cologne,+Germany&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Global&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Stockholm,+Sweden&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Westindische+buurt,+Amsterdam&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Memmingen&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Brussel,+Belgi%C3%AB&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=K%C3%B6ln&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Thessaloniki,+Greece&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Navarra,+Spain&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Zu+Hause&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Castilla-La+Mancha&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Planet+Earth+%F0%9F%8C%8D+cosmopolitan&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Sydney,+New+South+Wales&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Bayern,+Deutschland&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SIENA-ITALIA&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Melbourne,+Victoria&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Little+Rock,+USA&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Tokyo-to,+Japan&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Santa+Elena&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=-33.890559,151.2316&key=xxx-ue9Ldhd3gRLQjE
# "-33.890559,151.2316" not uniquely geocoded, using "2 cook rd, centennial park nsw 2021, australia"
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Improving+quality+of+life&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=iPhone:+42.363846,-83.469330&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Sydney,+New+South+Wales&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Greater+Sudbury+/+Grand+Sudbur&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=LANSING,+MI&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Paradise,+Newfoundland+and+Labrador&key=xxx-ue9Ldhd3gRLQjE
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=GTA&key=xxx-ue9Ldhd3gRLQjE

# %%
head(geoloc1)
# Out:
#   lon       lat
# 1 -74.00597 40.712775
# 2 -79.92236 -2.170998
# 3        NA        NA
# 4        NA        NA
# 5 -80.45249 -1.054723
# 6 -78.18341 -1.831239

# %%
#<************Writing geolocation into geoloc1.csv file***************> 
write.csv(geoloc1, file = "geoloc1.csv",row.names=FALSE, na="")

# %%
library(twitteR)
setup_twitter_oauth("4TvNeqKpfzrjy4lz7wDrR8f7f", "VvZ1uk91Xsoc30hVuRcnH3DOowOgh1Vbjp6QFGQNDb1mt25cHp", 
"766569222478573572-02R2OgdUuKqiT454C01xk4vYN1dFP9l", "5viPcLynoXxvSmu6FRDpWQ58CvKuTkoZGFIFx1lLxJwNS")
influenzaTweets2 <- searchTwitter("#flu", n=5000) #retrieve first tweets
df2_influenzaTweets <- twListToDF(influenzaTweets2)
# Out:
# [1] "Using direct authentication"

# %%
 #<************Writing Dataframe of tweets into df2_influenzaTweets.csv file***************>   
write.csv(df2_influenzaTweets, file = "df2_influenzaTweets.csv", row.names=FALSE, na="")

# %%
#look up users from tweets dataframes using screenName
users.data2 <- lookupUsers(df2_influenzaTweets$screenName) #look up users from tweets dataframes
userData2 <- twListToDF(users.data2)
userLocations2 <- userData2$location

# %%
#Remove the empty location
userLocations2_clean <- userLocations2[userLocations2!='']
head(userLocations2_clean)
# Out:
# [1] "NYC"                      "Nevada"
# [3] "West and Central Florida" "Nevada, MO"
# [5] "Maryland, USA"            "USA"

# %%
#convert it into data frame and save into csv
df2_userLocations2_clean <- as.data.frame(userLocations2_clean)
write.csv(df2_userLocations2_clean, file = "df2_userLocations2_clean.csv",row.names=FALSE, na="")

# %%
#Getting long and lat of all the locations using google api(geocode)
library(ggmap) 
library(ggplot2)
library(maptools)
locationdf2 <-read.csv(file="df2_userLocations2_clean.csv")
head(locationdf2)
geoloc1 <- geocode(as.character(locationdf2$userLocations2_clean))
# Out:
#   userLocations2_clean
# 1 NYC
# 2 Nevada
# 3 West and Central Florida
# 4 Nevada, MO
# 5 Maryland, USA
# 6 Western NY
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=NYC&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "NYC"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Nevada&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=West%20and%20Central%20Florida&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Nevada,%20MO&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Maryland,%20USA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Western%20NY&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Western NY"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Minneapolis,%20MN&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Minneapolis, MN"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=British%20Columbia,%20Canada&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York,%20USA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Philadelphia,%20Pa&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Cambridge&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Cambridge"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=US%20&%20Canada&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "US & Canada"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Atlanta,%20GA&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Mount%20Sinai%20Health%20System&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=St%20Louis,%20MO&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Laranjeiras&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Laranjeiras"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=S%C3%A3o%20Lu%C3%ADs,%20Brazil&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Living%20on%20airplanes&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Living on airplanes"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Shawnee%20OK&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Utah&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Vienna,%20VA&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Madison&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Washington,%20DC&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Twilightzone&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Santiago,%20Metropolitana%20de%20San&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Planet%20Earth&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York,%20USA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Pearl%20River,%20NY&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Bethesda,%20MD&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=North%20Pole&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,%20NC&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Elmwood%20Park,%20IL&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Indianapolis,%20IN&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Pittsburgh%20(Mt.%20Lebanon),%20PA&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Pittsburgh (Mt. Lebanon), PA"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=In%20a%20book,%20gardens%20or%20tube&sensor=false
# Warning message:
# “geocode failed with status ZERO_RESULTS, location = "In a book, gardens or tube"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Silver%20Spring,%20MD&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Silver Spring, MD"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Oblong,%20Il.&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Washington,%20DC&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Atlanta,%20GA&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Philadelphia,%20PA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Kinross,%20Scotland&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Ottawa,%20Canada&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Ottawa, Canada"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Planet%20Earth&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=NoVA,%20USA&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chicago,%20IL&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Kansas%20City,%20MO&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Northwest%20Amexem&sensor=false
# Warning message:
# “geocode failed with status ZERO_RESULTS, location = "Northwest Amexem"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Houston,%20TX&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=MN&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=San%20Francisco,%20CA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Newent,%20Gloucestershire&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=TX&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=US&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=LA%20and%20New%20York%20City&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York,%20NY&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20Jersey,%20USA&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=vb%20-%20la&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Texas,%20USA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=California,%20USA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Phoenix,%20AZ&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Providence,%20RI&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Eatonton,%20GA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Paraguay&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=MN&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Amsterdam,%20The%20Netherlands&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Connecticut&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Connecticut"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Lehigh%20Valley,%20PA/NJ&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Wolters%20Kluwer%20Health&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=York,%20PA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Fort%20Worth,%20TX&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Hillcrest,%20San%20Diego&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Hillcrest, San Diego"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Bronx,%20NY&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Cheshire&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=NYC&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Fredericksburg,%20VA&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chapel%20Hill,%20North%20Carolina&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Ames.DSM.Marshalltown&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Ames.DSM.Marshalltown"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Brockton,%20MA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chicago,%20IL&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Maryland,%20USA&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Maryland, USA"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Dallas/%20Fort-Worth&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Madison,%20WI&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Puerto%20Rico&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Phoenix,%20AZ&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=North%20Carolina&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Princeton,%20N.J.&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Atlanta,%20GA&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Atlanta, GA"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Austin,%20TX&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Austin, TX"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=
sensor=false
# Warning message:
# “geocode failed with status ZERO_RESULTS, location = "CT, NY, & MA"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Baldwin%20Park,%20CA&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Baldwin Park, CA"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Cornwall,%20UK&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=San%20Francisco,%20CA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Wexford,%20Ireland&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Cary,%20North%20Carolina&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=South%20Orange,%20NJ&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "South Orange, NJ"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Ottawa,%20Ontario&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Washington,%20DC&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Ontario,%20Canada&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Sugar%20Land,%20Texas&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Hamilton,%20NJ&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Ottawa,%20Ontario&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Brooklyn,%20NY&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York%20&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "New York "”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Cary,%20NC%20&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Cary, NC "”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Seattle,%20WA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=The%20#941&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "The #941"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Whittier,%20CA&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Whittier, CA"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Cambridgeshire%22West%20of%20Canada&sensor=false
# Warning message:
# “geocode failed with status ZERO_RESULTS, location = "Cambridgeshire"West of Canada"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Timmins,%20Ontario&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Florida&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Dublin%20Ireland&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Jakarta&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=North%20Miami%20Beach,%20Florida&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "North Miami Beach, Florida"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20Haven,%20CT&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Orlando,%20FL&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Columbus,%20OH&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Geelong,%20Victoria&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Sierra%20Mountains%20C.A.%20USA%20&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York,%20NY&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Atlanta,%20GA&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Ontario,%20Canada&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Des%20Moines,%20Iowa&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20Haven,%20CT,%20USA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20Jersey,%20USA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Dallas,%20TX&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Dallas, TX"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York,%20New%20York&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Dover,%20OH&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=M%C3%A9xico%20D.F.&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Los%20Angeles,%20CA&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Saline,%20MI&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,%20NC&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Mexico,%20D.F.&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Regina,%20Saskatchewan&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Regina, Saskatchewan"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Boston,%20MA&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=10%20Houston%20Locations&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Atlanta,%20GA&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Atlanta, GA"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York,%20NY&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Rosemont,%20Ill.&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Rosemont, Ill."”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Georgia,%20USA&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Georgia, USA"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Washington,%20DC&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chicago,%20IL&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=North%20Carolina&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20Jersey,%20USA&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "New Jersey, USA"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Washington,%20DC&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Washington, DC"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Jacksonville,%20FL&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Florida,%20USA&sensor=false

# %%
head(geoloc1)
# Out:
#   lon        lat
# 1         NA       NA
# 2 -116.41939 38.80261
# 3  -87.28459 39.62265
# 4  -94.35467 37.83921
# 5  -76.64127 39.04575
# 6         NA       NA

# %%
write.csv(geoloc1, file = "geoloc2.csv",row.names=FALSE, na="")

# %%
library(twitteR)
setup_twitter_oauth("4TvNeqKpfzrjy4lz7wDrR8f7f", "VvZ1uk91Xsoc30hVuRcnH3DOowOgh1Vbjp6QFGQNDb1mt25cHp", 
"766569222478573572-02R2OgdUuKqiT454C01xk4vYN1dFP9l", "5viPcLynoXxvSmu6FRDpWQ58CvKuTkoZGFIFx1lLxJwNS")
influenzaTweets3 <- searchTwitter("#influenza", n=5000) #retrieve first tweets
df3_influenzaTweets <- twListToDF(influenzaTweets3)
# Out:
# [1] "Using direct authentication"

# %%
 #<************Writing Dataframe of tweets into df3_influenzaTweets.csv file***************>   
write.csv(df3_influenzaTweets, file = "df3_influenzaTweets.csv", row.names=FALSE, na="")

# %%
#look up users from tweets dataframes using screenName
users.data3 <- lookupUsers(df3_influenzaTweets$screenName) #look up users from tweets dataframes
userData3 <- twListToDF(users.data3)
userLocations3 <- userData3$location

# %%
#Remove the empty location
userLocations3_clean <- userLocations3[userLocations3!='']
head(userLocations3_clean)
# Out:
# [1] "United States"       "Vermont, USA"        "Ciudad de México"
# [4] "Global"              "Portoviejo, Ecuador" "Galveston, TX"

# %%
#convert it into data frame and save into csv
df3_userLocations3_clean <- as.data.frame(userLocations3_clean)
sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Santiago%20de%20Chile&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Santiago de Chile"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Puerto%20Montt,%20Chile&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Puerto Montt, Chile"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Vi%C3%B1a%20del%20Mar,%20CHILE&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chile&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Chile"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Linares,%20Chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=La%20Florida&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Macar%C3%A1,%20Ecuador&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Macará, Ecuador"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Boston's%20Northern%20Suburbs&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Boston's Northern Suburbs"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Macara,%20Ecuador&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Catamayo,%20Ecuador&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Tena,%20Napo,%20Ecuador&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Dublin%20City,%20Ireland&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Morona%20Santiago,%20Ecuador&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Antofagasta,%20Chile&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Antofagasta, Chile"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=chile&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "chile"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Roma%20y%20Barcelona&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Santiago%20Metropolitan%20Region&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Santiago Metropolitan Region"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Santiago%20de%20Chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Arica-Chilee&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Loja,%20Ecuador&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Loja, Ecuador"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chile,%20Santiago&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Chile, Santiago"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Loja,%20Ecuador&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Loja, Ecuador"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Concepci%C3%B3n,%20Chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=M%C3%A9xico&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Loja&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chile&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Concepci%C3%B3n,%20Chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Ecuador&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Mundo&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=REGION%20DE%20LOS%20RIOS&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Copiap%C3%B3,%20Chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Miami,%20FL&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Llaullao%20Castro%20Chiloe%20&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chile&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Punta%20Arenas,%20Chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Cambridge,%20MA&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Guayaquil.ecuador.&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=DEUTSCHLAND&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Soutomaior,%20Pontevedra&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Santiago&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=constitucion,chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Iquique,%20Chile&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Iquique, Chile"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Santiago%20de%20Chile&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Phoenix,%20AZ&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Santiago%20&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Santiago "”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Quito,%20Ecuador&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Quito, Ecuador"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Santiago&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Los%20Angeles,%20CA&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Santiago,%20Chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chile&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Ecuador&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Guayaquil,%20Ecuador&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Washington/%20Geneva&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Washington/ Geneva"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Stockport,%20England&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=La%20Calera%20-%20Chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chicureo%20-%20Chile&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Ecuador&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Los%20Lagos,%20Chile&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=WHO%20Geneva&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=san%20nicolas,%20chile&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Gualaceo,%20Ecuador&sensor=false
# .Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Las%20Vegas,%20NV&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Las Vegas, NV"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Bristol,%20England&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Bristol, England"”.Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Santiago,%20Chile&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Santiago, Chile"”

# %%
head(geoloc3)
# Out:
#   lon       lat
# 1 -95.71289 37.090240
# 2 -72.57784 44.558803
# 3        NA        NA
# 4 -83.98110 34.114050
# 5 -80.45249 -1.054723
# 6        NA        NA

# %%
write.csv(geoloc3, file = "geoloc3.csv",row.names=FALSE, na="")

# %%
library(twitteR)
setup_twitter_oauth("4TvNeqKpfzrjy4lz7wDrR8f7f", "VvZ1uk91Xsoc30hVuRcnH3DOowOgh1Vbjp6QFGQNDb1mt25cHp", 
"766569222478573572-02R2OgdUuKqiT454C01xk4vYN1dFP9l", "5viPcLynoXxvSmu6FRDpWQ58CvKuTkoZGFIFx1lLxJwNS")
influenzaTweets4 <- searchTwitter("#flu", n=5000) #retrieve first tweets
df4_influenzaTweets <- twListToDF(influenzaTweets4)
# Out:
# [1] "Using direct authentication"

# %%
 #<************Writing Dataframe of tweets into df4_influenzaTweets.csv file***************>   
write.csv(df4_influenzaTweets, file = "df4_influenzaTweets.csv", row.names=FALSE, na="")

# %%
#look up users from tweets dataframes using screenName
users.data4 <- lookupUsers(df4_influenzaTweets$screenName) #look up users from tweets dataframes
userData4 <- twListToDF(users.data4)
userLocations4 <- userData4$location

# %%
#Remove the empty location
userLocations4_clean <- userLocations4[userLocations4!='']
head(userLocations4_clean)
# Out:
# [1] "Books at Amazon Books"     "Oporto, Portugal"
# [3] "The Wild West"             "Orlando, FL "
# [5] "Manhattan, NY"             "wwwwritersprofitguide.com"

# %%
#convert it into data frame and save into csv
df4_userLocations4_clean <- as.data.frame(userLocations4_clean)
write.csv(df4_userLocations4_clean, file = "df4_userLocations4_clean.csv",row.names=FALSE, na="")

# %%
#Getting long and lat of all the locations using google api(geocode)
library(ggmap) 
library(ggplot2)
library(maptools)
locationdf4 <-read.csv(file="df4_userLocations4_clean.csv")
head(locationdf4)
dim(locationdf4)
geoloc4 <- geocode(as.character(locationdf4$userLocations4_clean))
# Out:
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.csv(file = "df4_userLocations4_clean.csv")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")

# %%
head(geoloc4)
# Out:
#   lon       lat
# 1 -81.37924 28.53834
# 2 -73.97125 40.78306
# 3 -96.79699 32.77666
# 4 -87.62980 41.87811
# 5 -73.93957 42.81424
# 6 -75.52437 39.15817

# %%
write.csv(geoloc4, file = "geoloc.csv",row.names=FALSE, na="")
# Out:
# Error in is.data.frame(x): object 'geoloc4' not found
# Traceback:
#
# 1. write.csv(geoloc4, file = "geoloc.csv", row.names = FALSE, na = "")
# 2. eval.parent(Call)
# 3. eval(expr, p)
# 4. eval(expr, p)
# 5. write.table(geoloc4, file = "geoloc.csv", row.names = FALSE,
#  .     na = "", col.names = TRUE, sep = ",", dec = ".", qmethod = "double")
# 6. is.data.frame(x)

# %%
library(maps)
library(sp)    
library(maptools)
#This function is refer from https://stackoverflow.com/questions/8751497/latitude-longitude-coordinates-to-state-code-in-r
latlong2state <- function(pointsDF) {
    
    states <- map('state', fill=TRUE, col="transparent", plot=FALSE)
    IDs <- sapply(strsplit(states$names, ":"), function(x) x[1])
    states_sp <- map2SpatialPolygons(states, IDs=IDs,
                     proj4string=CRS("+proj=longlat +datum=WGS84"))

    pointsSP <- SpatialPoints(pointsDF, 
                    proj4string=CRS("+proj=longlat +datum=WGS84"))
    indices <- over(pointsSP, states_sp)
    stateNames <- sapply(states_sp@polygons, function(x) x@ID)
    stateNames[indices]
}
# Out:
# Checking rgeos availability: FALSE
#  	Note: when rgeos is not available, polygon geometry 	computations in maptools depend on gpclib,
#  	which has a restricted licence. It is disabled by default;
#  	to enable gpclib, type gpclibPermit()

# %%
#Getting all long and lat in a Dataframe and convert it to US sate location
geoLocData1 <- read.csv(file="geoloc1.csv",head=TRUE,sep=",") 
geoLocData2 <- read.csv(file="geoloc2.csv",head=TRUE,sep=",")
geoLocData3 <- read.csv(file="geoloc3.csv",head=TRUE,sep=",")
geoLocData4 <- read.csv(file="geoloc4.csv",head=TRUE,sep=",")
totalGeoData <-rbind(geoLocData1,geoLocData2,geoLocData3,geoLocData4)
dim(totalGeoData)
usStatelocation <- latlong2state(totalGeoData)
stateFreq <- table(usStatelocation)   #table is used to find grouping of states with corresponding frequencies
stateFreqDF <- as.data.frame(stateFreq)
# Out:
# [1] 6303    2

# %%
stateFreqDF
#write.csv(stateFreqDF, file = "stateFreqDF.csv",row.names=FALSE, na="")
# Out:
#    usStatelocation      Freq
# 1  alabama               16
# 2  arizona               79
# 3  arkansas              16
# 4  california           341
# 5  colorado              49
# 6  connecticut           40
# 7  delaware              10
# 8  district of columbia 123
# 9  florida              149
# 10 georgia              112
# 11 idaho                 12
# 12 illinois             108
# 13 indiana               52
# 14 iowa                  15
# 15 kansas                91
# 16 kentucky              39
# 17 louisiana             17
# 18 maine                 15
# 19 maryland             101
# 20 massachusetts        124
# 21 michigan              62
# 22 minnesota             50
# 23 mississippi            8
# 24 missouri              67
# 25 montana               17
# 26 nebraska              16
# 27 nevada                47
# 28 new hampshire         11
# 29 new jersey            86
# 30 new mexico            12
# 31 new york             152
# 32 north carolina       103
# 33 north dakota           4
# 34 ohio                  78
# 35 oklahoma              55
# 36 oregon                26
# 37 pennsylvania         166
# 38 rhode island          23
# 39 south carolina        29
# 40 south dakota           1
# 41 tennessee             52
# 42 texas                324
# 43 utah                  36
# 44 vermont               15
# 45 virginia              89
# 46 washington            45
# 47 west virginia          8
# 48 wisconsin             51
# 49 wyoming                1

# %%
library(ggplot2)
library(maptools)
library(maps)
pFreqData <- read.csv(file="stateFreqDF.csv")
head(pFreqData)
library(RColorBrewer)

myPalette <- colorRampPalette(rev(brewer.pal(11, "Spectral")))
us <- map_data("state")
head(us)

gg <- ggplot()
gg <- gg + geom_map(data=us, map=us,aes(x = long, y = lat, map_id=region),
                    fill="#ffffff", color="#ffffff", size=1)
gg <- gg + geom_map(data=pFreqData, map=us,
                    aes(fill=Freq, map_id=pFreqData$usStatelocation),
                    color="#ffffff", size=0.15)
gg <- gg + labs(x="", y="", fill ="Frequency", title = "2017-18 Infulenza and Flu Tweets Frequency Indicator")
gg <- gg + coord_map("albers", lat0 = 39, lat1 = 45) 
gg <- gg + theme(panel.border = element_blank(), panel.background = element_blank(), axis.ticks = element_blank(),
                axis.text = element_blank(), plot.title = element_text(size = 15, face = "bold"))
gg <- gg + scale_fill_gradientn(colours = myPalette(300), limits=c(0,350))
gg
# Out:
# Loading required package: sp
# Checking rgeos availability: FALSE
#  	Note: when rgeos is not available, polygon geometry 	computations in maptools depend on gpclib,
#  	which has a restricted licence. It is disabled by default;
#  	to enable gpclib, type gpclibPermit()
#   usStatelocation Freq
# 1 alabama          16
# 2 arizona          79
# 3 arkansas         16
# 4 california      341
# 5 colorado         49
# 6 connecticut      40
#   long      lat      group order region  subregion
# 1 -87.46201 30.38968 1     1     alabama NA
# 2 -87.48493 30.37249 1     2     alabama NA
# 3 -87.52503 30.37249 1     3     alabama NA
# 4 -87.53076 30.33239 1     4     alabama NA
# 5 -87.57087 30.32665 1     5     alabama NA
# 6 -87.58806 30.32665 1     6     alabama NA
# Warning message:
# “Ignoring unknown aesthetics: x, y”
# plot without title
